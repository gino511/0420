# %%
# !pip install Flask pyngrok line-bot-sdk requests google-genai

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3ClDmzH22sqWEbRSdze4yo4Zgpf_7ycL9z7EcZyfCYuL92PAR")

# %%
from flask import Flask
import threading

app = Flask(__name__)

@app.route('/')
def home():
    # ⚠️ 作業改這裡
    return "<h1>明新科技大學 李宇倫</h1>"

def run():
    app.run(host="0.0.0.0", port=5051)

thread = threading.Thread(target=run)
thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5051
#  * Running on http://172.28.0.12:5051
# INFO:werkzeug:Press CTRL+C to quit

# %%
from pyngrok import ngrok

# 清掉舊連線
ngrok.kill()

# 開新連線
tunnel = ngrok.connect(5051)

print(tunnel.public_url)
# Out:
# https://gap-unison-monotone.ngrok-free.dev
